# %% [markdown]
# # Task: Evaluate ability to use MINTAKA as a basic dataset for answer type prediction
#
# https://www.notion.so/msalnikov/Evaluate-ability-to-use-MINTAKA-as-a-basic-dataset-for-answer-type-prediction-cdbaa44b9f904d5882a28840ae04bcfd?pvs=4

# %%
import datasets
import pandas as pd
from transformers import T5ForConditionalGeneration, AutoTokenizer
from tqdm.auto import tqdm
from joblib import Parallel, delayed

from kbqa.seq2seq.eval import predict_answers as seq2seq_predict_answers
from kbqa.candidate_selection.question_to_rank_by_instance_of import QuestionToRankInstanceOfSimple

import nltk

# %%
from typing import Optional

import requests
from joblib import Memory
from pywikidata import Entity

memory = Memory('/tmp/cache', verbose=0)


@memory.cache
def get_wd_search_results(
    search_string: str,
    max_results: int = 500,
    language: str = 'en',
    mediawiki_api_url: str = "https://www.wikidata.org/w/api.php",
    user_agent: str = None,
) -> list:
    params = {
        'action': 'wbsearchentities',
        'language': language,
        'search': search_string,
        'format': 'json',
        'limit': 50
    }

    user_agent = "pywikidata" if user_agent is None else user_agent
    headers = {
        'User-Agent': user_agent
    }

    cont_count = 1
    results = []
    while cont_count > 0:
        params.update({'continue': 0 if cont_count == 1 else cont_count})

        reply = requests.get(mediawiki_api_url, params=params, headers=headers)
        reply.raise_for_status()
        search_results = reply.json()

        if search_results['success'] != 1:
            raise Exception('WD search failed')
        else:
            for i in search_results['search']:
                results.append(i['id'])

        if 'search-continue' not in search_results:
            cont_count = 0
        else:
            cont_count = search_results['search-continue']

        if cont_count > max_results:
            break

    return results

# %%
types_df = pd.read_csv(
    './mintaka_train_simpleq_answer_types.txt',
    sep='\t',
    names=['id', 'answer_id', 'type_id'],
)
types_df.head()
# Out:
#          id answer_id type_id
# 0  cf871296   Q185107      Q5
# 1  8239c2cd   Q669749  Q11424
# 2  058d3478   Q976022      Q5
# 3  e347e0ab   Q192724  Q11424
# 4  d6ef9a28   Q312098      Q5

# %%
df: pd.DataFrame = datasets.load_dataset('AmazonScience/mintaka', split='train').to_pandas()
df.head()
# Out:
# No config specified, defaulting to: mintaka/en
# Found cached dataset mintaka (/root/.cache/huggingface/datasets/AmazonScience___mintaka/en/1.0.0/bb35d95f07aed78fa590601245009c5f585efe909dbd4a8f2a4025ccf65bb11d)
#          id lang                                           question  \
# 0  a9011ddf   en  What is the seventh tallest mountain in North ...
# 1  2723bb1b   en  Which actor was the star of Titanic and was bo...
# 2  88349c89   en  Which actor starred in Vanilla Sky and was mar...
# 3  bff78c91   en  What year was the first book of the A Song of ...
# 4  982450cf   en           Who is the youngest current US governor?
#
#           answerText   category complexityType  \
# 0      Mount Lucania  geography        ordinal
# 1  Leonardo DiCaprio     movies   intersection
# 2         Tom Cruise     movies   intersection
# 3               1996      books        generic
# 4       Ron DeSantis   politics    superlative
#
#                                       questionEntity  \
# 0  [{'name': 'Q49', 'entityType': 'entity', 'labe...
# 1  [{'name': 'Q44578', 'entityType': 'entity', 'l...
# 2  [{'name': 'Q174346', 'entityType': 'entity', '...
# 3  [{'name': 'Q45875', 'entityType': 'entity', 'l...
# 4  [{'name': 'Q889821', 'entityType': 'entity', '...
#
#                                         answerEntity
# 0   [{'name': 'Q1153188', 'label': 'Mount Lucania'}]
# 1  [{'name': 'Q38111', 'label': 'Leonardo DiCapri...
# 2        [{'name': 'Q37079', 'label': 'Tom Cruise'}]
# 3                                                 []
# 4    [{'name': 'Q3105215', 'label': 'Ron DeSantis'}]

# %%
df = df.merge(types_df, on='id')
df.head()
# Out:
#          id lang                                           question  \
# 0  cf871296   en  Who was the president of Argentina from 1989 t...
# 1  8239c2cd   en  What movie won the first Golden Globe award fo...
# 2  058d3478   en  Who played Christian Grey in Fifty Shades of G...
# 3  e347e0ab   en  What was the first movie in the Marvel Cinemat...
# 4  d6ef9a28   en  Who won the Academy Award for Best Actor in 1950?
#
#                answerText  category complexityType  \
# 0            Carlos Menem  politics        generic
# 1  The Song of Bernadette    movies        generic
# 2            Jamie Dornan    movies        generic
# 3                Iron Man    movies        generic
# 4             Jose Ferrer    movies        generic
#
#                                       questionEntity  \
# 0  [{'name': 'Q414', 'entityType': 'entity', 'lab...
# 1  [{'name': 'Q102427', 'entityType': 'entity', '...
# 2  [{'name': 'Q110110619', 'entityType': 'entity'...
# 3  [{'name': 'Q642878', 'entityType': 'entity', '...
# 4  [{'name': 'Q103916', 'entityType': 'entity', '...
#
#                                         answerEntity answer_id type_id
# 0     [{'name': 'Q185107', 'label': 'Carlos Menem'}]   Q185107      Q5
# 1  [{'name': 'Q669749', 'label': 'The Song of Ber...   Q669749  Q11424
# 2     [{'name': 'Q976022', 'label': 'Jamie Dornan'}]   Q976022      Q5
# 3         [{'name': 'Q192724', 'label': 'Iron Man'}]   Q192724  Q11424
# 4      [{'name': 'Q312098', 'label': 'José Ferrer'}]   Q312098      Q5

# %%
model = T5ForConditionalGeneration.from_pretrained('/mnt/storage/QA_System_Project/seq2seq_runs/wdsq_tunned/google_t5-large-ssm-nq/models/checkpoint-4000/')
tokenizer = AutoTokenizer.from_pretrained('/mnt/storage/QA_System_Project/seq2seq_runs/wdsq_tunned/google_t5-large-ssm-nq/models/checkpoint-4000/')

# %%
dataset = datasets.Dataset.from_pandas(df).map(
    lambda batch: tokenizer(
        batch['question'],
        padding='max_length',
        truncation=True,
        max_length=64,
    ),
    batched=True,
)
columns = [
    "input_ids",
    "attention_mask",
]
dataset.set_format(type="torch", columns=columns)
# Out:
# Map:   0%|          | 0/1252 [00:00<?, ? examples/s]

# %%
device = 'cuda:2'
generated_answers = seq2seq_predict_answers(
    model=model.to(device),
    tokenizer=tokenizer,
    dataset=dataset,
    num_beams=200,
    num_return_sequences=200,
    num_beam_groups=5,
    diversity_penalty=0.1,
    batch_size=2,
    device=device,
)
# Out:
# evaluate model:   0%|          | 0/626 [00:00<?, ?it/s]
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/transformers/generation/beam_search.py:198: UserWarning: Passing `max_length` to BeamSearchScorer is deprecated and has no effect. `max_length` should be passed directly to `beam_search(...)`, `beam_sample(...)`, or `group_beam_search(...)`.
#   warnings.warn(

# %%
generated_answer_df = pd.DataFrame(generated_answers)
generated_answer_df.head()
# Out:
#                                answer_0  \
# 0  Leopoldo Fortunato Galtieri Castelli
# 1            The Grasshopper Lies Heavy
# 2                  James "Jamie" Dornan
# 3                    Marvel's Daredevil
# 4                        Sidney Poitier
#
#                                     answer_1  \
# 0                 Luis Guillermo Sols Rivera
# 1  Underworld: The Curse of the Blood Rubies
# 2                       James "Jamie" Dornan
# 3                      Marvel's The Avengers
# 4                           Daniel Day-Lewis
#
#                                answer_2                            answer_3  \
# 0  Leopoldo Fortunato Galtieri Castelli  Augusto José Ramón Pinochet Ugarte
# 1            The Grasshopper Lies Heavy            Bridget Moynahan's Diary
# 2                          James Dornan                        Jamie Dornan
# 3                    Marvel's Daredevil               Marvel's The Avengers
# 4                        Sidney Poitier                     Harry Belafonte
#
#                     answer_4              answer_5  \
# 0               lvaro Ugarte       Lázaro Cárdenas
# 1  I'll See You in My Dreams        Les Misérables
# 2                 Idris Elba  James "Jamie" Dornan
# 3     Spider-Man: Homecoming    Marvel's Daredevil
# 4           Daniel Day-Lewis        Sidney Poitier
#
#                                     answer_6                    answer_7  \
# 0                          Enrique Pea Nieto  Luis Guillermo Sols Rivera
# 1  Underworld: The Curse of the Blood Rubies        Strangers on a Train
# 2                              Bill Skarsgrd           Adrian McLoughlin
# 3                 Captain America: Civil War     Avengers: Age of Ultron
# 4                            Harry Belafonte            Daniel Day-Lewis
#
#                                answer_8                 answer_9  ...  \
# 0             Luis Guillermo Sols Vidal            lvaro Obrador  ...
# 1                 Bridget Jones's Diary  Sleeping with the Enemy  ...
# 2               Matthew Quincy Daddario             James Dornan  ...
# 3  Marvel's The Avengers: Age of Ultron   Spider-Man: Homecoming  ...
# 4                          Robert Donat          Ernest Borgnine  ...
#
#                             answer_190  \
# 0                     Leopoldo Evoluti
# 1           L'Italiano by Luchino Visi
# 2                     Freddie Highmore
# 3  Marvel's The Marvelous Land of Ymir
# 4                        Claude Berris
#
#                                    answer_191  \
# 0             Luis Guillermo Stábile Carrillo
# 1                   In the Name of the Father
# 2                     James "Jamie" Stevenson
# 3  Marvel's The Avengers: The Avengers (2012)
# 4                                Donald Woods
#
#                                answer_192                          answer_193  \
# 0  Leopoldo Fortunato Galtieri Campanella                    Ricardo Rosselló
# 1  Underworld: The World's Most Dangerous  Underworld: The Curse of the Nerds
# 2                    James "Jamie" Lepley                James "Jamie" Garner
# 3            Marvel's The Avengers (2012)                X-Men Origins: Woden
# 4                             Victor Jory              William Theodore Wyler
#
#                                 answer_194                       answer_195  \
# 0                             Buenos Aires               Juan Manuel Santos
# 1           Dead Man's Chest: Resurrection  Erin Brockovich and His Friends
# 2                    James "Jamie" Duczmal                       Eric Andre
# 3  Marvel's The Marvelous Land of Piranha!                 Marvel's Dracula
# 4               William Theodore Wadsworth                    Frank Sinatra
#
#                            answer_196                         answer_197  \
# 0      Luis Guillermo Bartolomeu Dias                       Carlos Menem
# 1       Strangers on a Strange Planet  Underworld: The Curse of the Nerd
# 2               James "Jamie" Gleeson               James "Jamie" Bluher
# 3  Captain America: Apocalypse (2003)              Marvel’s The Avengers
# 4                        Oscar Levant           William Theodore Henlein
#
#                                   answer_198  \
# 0                 Luis Guillermo Sols Trevio
# 1  Underworld: The Curse of the Blood Rubies
# 2                             D. W. Weissman
# 3             Captain America: The Civil War
# 4                                Louis Blinn
#
#                                 answer_199
# 0         Luis Guillermo Sols Muoz Barrios
# 1  Dead Man's Chest: The Story of the Dead
# 2                                Eric Bana
# 3                     Marvel's Superheroes
# 4               William Theodore Struthers
#
# [5 rows x 200 columns]

# %%
import os
os.environ['TOKENIZERS_PARALLELISM'] = 'false'


def get_type_by_act(row):
    candidates_entities = [get_wd_search_results(label, 1)[:1] for label in row.unique().tolist()]
    candidates_entities = [l[0] for l in candidates_entities if len(l) > 0]

    act_typing_result = QuestionToRankInstanceOfSimple(
        '',
        [],
        candidates_entities,
    ).answer_instance_of
    return [e.idx for e in act_typing_result]


act_typing_results = Parallel(n_jobs=2)(
    delayed(get_type_by_act)(row) 
    for _,row in tqdm(generated_answer_df.iterrows(), total=generated_answer_df.index.size)
)
# act_typing_results = [
#     get_type_by_act(row)
#     for _,row in tqdm(generated_answer_df.iterrows(), total=generated_answer_df.index.size)
# ]

df['predicted_types_id'] = act_typing_results
# Out:
#   0%|          | 0/1252 [00:00<?, ?it/s]

# %%
df.apply(
    lambda row: row['type_id'] in row['predicted_types_id'],
    axis=1
).sum() / df.index.size
# Out:
# 0.6837060702875399

# %%
df.apply(
    lambda row: row['type_id'] in row['predicted_types_id'][:1],
    axis=1
).sum() / df.index.size
# Out:
# 0.5838658146964856
